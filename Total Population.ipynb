# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
Total_Population = pd.read_csv("TotalPop.csv")
Total_Population
# Out:
#     Year   Population   Yearly % Change   Yearly Change
# 0   2015    321418820              0.78           2511419
# 1   2014    318907401              0.77           2480006
# 2   2013    316427395              0.73           2324772
# 3   2012    314102623              0.75           2383766
# 4   2011    311718857              0.76           2371994
# 5   2010    309346863              0.75           2340313
# 6   2009    307006550              0.86           2631704
# 7   2008    304374846              0.93           2794951
# 8   2007    301579895              1.00           2986683
# 9   2006    298593212              0.96           2840061
# 10  2005    295753151              0.92           2707412
# 11  2004    293045739              0.94           2719321
# 12  2003    290326418              0.88           2522504
# 13  2002    287803914              0.95           2722358
# 14  2001    285081556              1.03           2909599
# ...

# %%
Year = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
Population = [282171957, 285081556, 287803914, 287803914, 293045739, 295753151 , 298593212, 301579895, 304374846,307006550,309346863, 311718857,314102623,316427395,318907401,321418820]

# %%
plt.scatter(Year, Population, marker="*", facecolors="green", edgecolors="black")
# Out:
# <img src="data:image/png;base64,..." width="497.45454545454544">

# %%
plt.title("US Total Population 2000-2015")
plt.ylabel("Population (100Mil)")
plt.xlabel("Years")
plt.xlim(1999,2016)
plt.grid()

# %%
plt.show()
